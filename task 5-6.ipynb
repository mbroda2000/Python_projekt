# %% [markdown]
# <a href="https://colab.research.google.com/github/mbroda2000/Python_projekt/blob/michal/task%205-6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# 5. interesting research questions and observations that can be derived from data
#
# more men work as devs than women
# python is the most popular
# More peole with Dev Branch havn't got metalHealth
#
#
# 6. features that do not seem important in context of potential problems
# *Age
# *Emloyment
# *Employed

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
import pandas as pd
data = pd.read_csv('drive/MyDrive/Data_ML.csv')

# %%
data.head()
# Out:
#    Unnamed: 0  Age Accessibility        EdLevel  Employment Gender  \
# 0           0  <35            No         Master           1    Man
# 1           1  <35            No  Undergraduate           1    Man
# 2           2  <35            No         Master           1    Man
# 3           3  <35            No  Undergraduate           1    Man
# 4           4  >35            No            PhD           0    Man
#
#   MentalHealth MainBranch  YearsCode  YearsCodePro    Country  PreviousSalary  \
# 0           No        Dev          7             4     Sweden         51552.0
# 1           No        Dev         12             5      Spain         46482.0
# 2           No        Dev         15             6    Germany         77290.0
# 3           No        Dev          9             6     Canada         46135.0
# 4           No     NotDev         40            30  Singapore        160932.0
#
#                                       HaveWorkedWith  ComputerSkills  Employed
# ...

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

dev_data = data[data['MainBranch'] == 'Dev']

sns.countplot(x='Gender', data=dev_data)
plt.title("How many Genders work as Devs")
plt.xlabel("Gender")
plt.ylabel("Count")
plt.show()
